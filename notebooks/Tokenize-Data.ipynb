# %% [markdown]
# # Tokenize Data
# Extract questions directly from mongoDB and dump to CSV file. Perform tokenization and tf-idf analysis.
#
# `mongoexport -h localhost -d stackoverflow -c posts --type=csv --fields Id,Title,Tags -q '{"PostTypeId":"1"}' --out questions_title_only.csv`

# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import re
import spacy

# %%
from spacy.lang.en.stop_words import STOP_WORDS
nlp = spacy.load('en_core_web_lg')

# %%
def mkstr_tags(tags):
    """
    Remove the square brackets and quotes to make 
    space separated strings.
    """
    val = re.sub('["\[\]]*', '', tags).replace(',', ' ')
    return val

# %%
def split_tags(tags):
    """
    Split tags string into a list
    """
    val = tags.split(' ')
    return val

# %% [markdown]
# ## Read in the questions Titles and Tags and create strings
# Here we want to separate the tags into list and then concatenate them.

# %%
FILE = 'questions_with_scores.csv'
df = pd.read_csv(FILE)

# %%
processed_tags = df['Tags'].apply(mkstr_tags)
df['Tags'] = processed_tags
df['Score'] = df['Score'].astype(int)
df['Data'] = df['Title'] + ' ' + df['Tags']

# %%
df.head(10)
# Out:
#          Id                                              Title  \
# 0  33679237  Elasticsearch include field in result set of a...
# 1  33679239                             find array item in PHP
# 2  33679246           Best Way to View my TukeyHSD Output in R
# 3  33679249  PDOStatement not returning result in Drupal views
# 4  33679252  Getting images dynamically and placing at thei...
# 5  33679254                     Query Parameter Use in Valence
# 6  33679257  Cannot initialize the indexer process Magento 1.9
# 7  33679260  how to remove bootstrap tags input Events from...
# 8  33679261  create a class that changes uppercase to lower...
# 9  33679265                         Iterable.forEach(Consumer)
#
#                                           Tags  Score
# 0                            ["elasticsearch"]      0
# 1                                      ["php"]      1
# 2                                        ["r"]      0
# 3    ["php","mysql","drupal","pdo","drupal-7"]      1
# 4    ["android","html","xml","image","layout"]      0
# 5             ["api","desire2learn","valence"]      0
# 6       ["sql","database","magento","catalog"]      0
# 7  ["javascript","jquery","twitter-bootstrap"]      0
# 8                            ["java","stream"]      0
# 9                           ["java","foreach"]      0

# %% [markdown]
# Concatenate question title and tags together to form strings for parsing

# %%
from collections import Counter
tags_list = list(df['Tags'].apply(split_tags).values)
flat_list = [item for sublist in tags_list for item in sublist]
tags_counted = Counter(flat_list)
tags_counted.most_common()
# Out:
# [('javascript', 220026),
#  ('java', 187044),
#  ('php', 155471),
#  ('android', 151764),
#  ('c#', 149508),
#  ('python', 131868),
#  ('jquery', 119539),
#  ('html', 101248),
#  ('ios', 78798),
#  ('c++', 73186),
#  ('css', 72179),
#  ('mysql', 67640),
#  ('sql', 58053),
#  ('asp.net', 37773),
#  ('ruby-on-rails', 36610),
#  ('arrays', 36309),
#  ('c', 36107),
#  ('objective-c', 34773),
#  ('angularjs', 33940),
#  ('r', 33516),
#  ('node.js', 33063),
#  ('json', 32258),
#  ('sql-server', 29255),
#  ('.net', 27238),
#  ('swift', 25844),
#  ('ruby', 24446),
#  ('regex', 24394),
#  ('ajax', 24181),
#  ('django', 22321),
#  ('xml', 21662),
#  ('linux', 21413),
#  ('iphone', 20579),
#  ('asp.net-mvc', 20368),
#  ('excel', 19497),
#  ('database', 18061),
#  ('spring', 18039),
#  ('wordpress', 17971),
#  ('angular', 17304),
#  ('string', 16562),
#  ('wpf', 16300),
#  ('html5', 15745),
#  ('python-3.x', 15448),
#  ('xcode', 14857),
#  ('eclipse', 14459),
#  ('vb.net', 14350),
#  ('windows', 14324),
#  ('mongodb', 14292),
#  ('multithreading', 13656),
#  ('bash', 13355),
#  ('vba', 13248),
#  ('git', 13069),
#  ('twitter-bootstrap', 12911),
#  ('reactjs', 12757),
#  ('laravel', 12591),
#  ('oracle', 12276),
#  ('python-2.7', 12146),
#  ('forms', 11763),
#  ('postgresql', 11384),
#  ('image', 11196),
#  ('scala', 10905),
#  ('macos', 10848),
#  ('facebook', 10747),
#  ('matlab', 10711),
#  ('pandas', 10670),
#  ('algorithm', 10660),
#  ('excel-vba', 10525),
#  ('list', 10483),
#  ('apache', 10430),
#  ('css3', 10352),
#  ('entity-framework', 9616),
#  ('swing', 9539),
#  ('visual-studio', 9529),
#  ('winforms', 9327),
#  ('performance', 9285),
#  ('hibernate', 9232),
#  ('function', 8830),
#  ('qt', 8668),
#  ('maven', 8564),
#  ('rest', 8473),
#  ('shell', 8453),
#  ('typescript', 8360),
#  ('linq', 8342),
#  ('.htaccess', 8327),
#  ('amazon-web-services', 8302),
#  ('symfony', 8267),
#  ('api', 8244),
#  ('cordova', 8185),
#  ('codeigniter', 7955),
#  ('sqlite', 7925),
#  ('azure', 7855),
#  ('powershell', 7759),
#  ('loops', 7730),
#  ('csv', 7501),
#  ('google-maps', 7497),
#  ('file', 7414),
#  ('firebase', 7396),
#  ('uitableview', 7390),
#  ('selenium', 7368),
#  ('google-chrome', 7348),
#  ('perl', 7113),
#  ('class', 7078),
#  ('numpy', 6964),
#  ('unit-testing', 6929),
#  ('sorting', 6923),
#  ('sockets', 6919),
#  ('android-layout', 6912),
#  ('android-studio', 6891),
#  ('web-services', 6786),
#  ('date', 6732),
#  ('ruby-on-rails-3', 6680),
#  ('sql-server-2008', 6547),
#  ('validation', 6539),
#  ('spring-mvc', 6460),
#  ('opencv', 6418),
#  ('xaml', 6240),
#  ('express', 6224),
#  ('asp.net-mvc-4', 6223),
#  ('listview', 6164),
#  ('tsql', 6110),
#  ('c++11', 6065),
#  ('jsp', 6020),
#  ('email', 6004),
#  ('http', 5982),
#  ('apache-spark', 5768),
#  ('ubuntu', 5752),
#  ('visual-studio-2010', 5561),
#  ('docker', 5534),
#  ('datetime', 5494),
#  ('batch-file', 5489),
#  ('parsing', 5446),
#  ('dictionary', 5417),
#  ('pointers', 5387),
#  ('oop', 5357),
#  ('android-fragments', 5345),
#  ('for-loop', 5324),
#  ('spring-boot', 5316),
#  ('object', 5284),
#  ('hadoop', 5214),
#  ('if-statement', 5195),
#  ('wcf', 5184),
#  ('google-app-engine', 5174),
#  ('security', 5159),
#  ('user-interface', 5133),
#  ('variables', 5129),
#  ('dataframe', 5126),
#  ('asp.net-mvc-3', 5101),
#  ('ruby-on-rails-4', 5063),
#  ('haskell', 5061),
#  ('templates', 4963),
#  ('react-native', 4963),
#  ('ms-access', 4898),
#  ('session', 4844),
#  ('magento', 4813),
#  ('jquery-ui', 4771),
#  ('unix', 4764),
#  ('pdf', 4741),
#  ('tomcat', 4714),
#  ('ssl', 4697),
#  ('delphi', 4684),
#  ('unity3d', 4680),
#  ('authentication', 4628),
#  ('elasticsearch', 4501),
#  ('jpa', 4497),
#  ('debugging', 4489),
#  ('xamarin', 4482),
#  ('facebook-graph-api', 4456),
#  ('matplotlib', 4396),
#  ('d3.js', 4349),
#  ('animation', 4347),
#  ('nginx', 4319),
#  ('jsf', 4297),
#  ('actionscript-3', 4287),
#  ('tensorflow', 4225),
#  ('curl', 4225),
#  ('internet-explorer', 4219),
#  ('asynchronous', 4202),
#  ('ionic-framework', 4199),
#  ('url', 4193),
#  ('redirect', 4161),
#  ('jenkins', 4150),
#  ('go', 4118),
#  ('firefox', 4066),
#  ('github', 4065),
#  ('generics', 4057),
#  ('recursion', 4054),
#  ('selenium-webdriver', 4040),
#  ('post', 4038),
#  ('button', 3987),
#  ('asp.net-web-api', 3982),
#  ('inheritance', 3981),
#  ('gradle', 3966),
#  ('heroku', 3948),
#  ('ipad', 3936),
#  ('opengl', 3917),
#  ('svg', 3884),
#  ('testing', 3868),
#  ('join', 3862),
#  ('gcc', 3832),
#  ('web', 3825),
#  ('matrix', 3800),
#  ('servlets', 3798),
#  ('canvas', 3790),
#  ('assembly', 3789),
#  ('xslt', 3769),
#  ('android-intent', 3761),
#  ('mod-rewrite', 3750),
#  ('exception', 3747),
#  ('cakephp', 3733),
#  ('intellij-idea', 3724),
#  ('meteor', 3724),
#  ('cocoa', 3722),
#  ('select', 3717),
#  ('caching', 3702),
#  ('dom', 3699),
#  ('arraylist', 3687),
#  ('math', 3682),
#  ('razor', 3661),
#  ('image-processing', 3642),
#  ('laravel-5', 3639),
#  ('video', 3566),
#  ('grails', 3549),
#  ('javafx', 3544),
#  ('search', 3538),
#  ('winapi', 3526),
#  ('jquery-mobile', 3517),
#  ('xpath', 3516),
#  ('machine-learning', 3512),
#  ('stored-procedures', 3508),
#  ('c#-4.0', 3499),
#  ('audio', 3480),
#  ('iis', 3480),
#  ('logging', 3473),
#  ('encryption', 3465),
#  ('java-ee', 3460),
#  ('cookies', 3430),
#  ('networking', 3407),
#  ('iframe', 3404),
#  ('flash', 3386),
#  ('events', 3351),
#  ('checkbox', 3337),
#  ('memory', 3299),
#  ('multidimensional-array', 3298),
#  ('visual-studio-2012', 3296),
#  ('ember.js', 3264),
#  ('google-maps-api-3', 3247),
#  ('vector', 3244),
#  ('cocoa-touch', 3236),
#  ('random', 3221),
#  ('activerecord', 3215),
#  ('jdbc', 3208),
#  ('amazon-s3', 3202),
#  ('backbone.js', 3199),
#  ('android-activity', 3183),
#  ('gridview', 3156),
#  ('input', 3152),
#  ('mysqli', 3113),
#  ('mobile', 3109),
#  ('ggplot2', 3105),
#  ('plot', 3103),
#  ('npm', 3096),
#  ('serialization', 3082),
#  ('model-view-controller', 3076),
#  ('core-data', 3062),
#  ('mongoose', 3032),
#  ('flask', 3017),
#  ('optimization', 3013),
#  ('amazon-ec2', 3006),
#  ('methods', 2987),
#  ('webpack', 2983),
#  ('awk', 2982),
#  ('visual-c++', 2970),
#  ('visual-studio-2015', 2952),
#  ('text', 2946),
#  ('soap', 2935),
#  ('tkinter', 2903),
#  ('firebase-database', 2903),
#  ('extjs', 2895),
#  ('twitter-bootstrap-3', 2891),
#  ('indexing', 2837),
#  ('layout', 2832),
#  ('windows-phone-8', 2830),
#  ('twitter', 2821),
#  ('file-upload', 2819),
#  ('mvvm', 2812),
#  ('knockout.js', 2789),
#  ('windows-phone-7', 2722),
#  ('boost', 2720),
#  ('asp.net-core', 2718),
#  ('pdo', 2717),
#  ('struct', 2707),
#  ('netbeans', 2702),
#  ('design-patterns', 2702),
#  ('ios7', 2702),
#  ('google-chrome-extension', 2679),
#  ('vim', 2656),
#  ('ssh', 2638),
#  ('vue.js', 2621),
#  ('groovy', 2620),
#  ('sed', 2618),
#  ('google-apps-script', 2613),
#  ('highcharts', 2608),
#  ('time', 2581),
#  ('reporting-services', 2579),
#  ('data-structures', 2569),
#  ('dynamic', 2557),
#  ('paypal', 2556),
#  ('django-models', 2541),
#  ('memory-management', 2541),
#  ('lambda', 2536),
#  ('graph', 2532),
#  ('charts', 2529),
#  ('junit', 2511),
#  ('dll', 2486),
#  ('primefaces', 2484),
#  ('replace', 2462),
#  ('foreach', 2454),
#  ('plugins', 2453),
#  ('ecmascript-6', 2441),
#  ('svn', 2440),
#  ('browser', 2431),
#  ('yii', 2409),
#  ('https', 2368),
#  ('login', 2363),
#  ('unicode', 2352),
#  ('spring-security', 2349),
#  ('file-io', 2343),
#  ('webview', 2323),
#  ('gwt', 2320),
#  ('service', 2313),
#  ('hash', 2310),
#  ('solr', 2301),
#  ('sharepoint', 2293),
#  ('cmd', 2287),
#  ('while-loop', 2283),
#  ('web-scraping', 2275),
#  ('plsql', 2271),
#  ('angularjs-directive', 2263),
#  ('printing', 2257),
#  ('encoding', 2253),
#  ('drop-down-menu', 2249),
#  ('woocommerce', 2248),
#  ('neo4j', 2236),
#  ('makefile', 2236),
#  ('playframework', 2236),
#  ('tfs', 2235),
#  ('android-recyclerview', 2232),
#  ('filter', 2229),
#  ('reflection', 2220),
#  ('scroll', 2187),
#  ('visual-studio-2013', 2182),
#  ('xamarin.forms', 2179),
#  ('utf-8', 2176),
#  ('dependency-injection', 2175),
#  ('ios5', 2175),
#  ('datagridview', 2167),
#  ('doctrine2', 2165),
#  ('tcp', 2163),
#  ('redux', 2163),
#  ('websocket', 2158),
#  ('uiview', 2156),
#  ('zend-framework', 2150),
#  ('oracle11g', 2142),
#  ('design', 2139),
#  ('command-line', 2133),
#  ('database-design', 2129),
#  ('view', 2128),
#  ('collections', 2123),
#  ('google-analytics', 2115),
#  ('jsf-2', 2111),
#  ('rspec', 2104),
#  ('android-listview', 2102),
#  ('split', 2078),
#  ('import', 2069),
#  ('oauth', 2062),
#  ('jar', 2057),
#  ('data-binding', 2048),
#  ('kendo-ui', 2043),
#  ('silverlight', 2042),
#  ('timer', 2041),
#  ('vbscript', 2036),
#  ('error-handling', 2033),
#  ('swift3', 2031),
#  ('html-table', 2013),
#  ('deployment', 2006),
#  ('hive', 1998),
#  ('sass', 1998),
#  ('uwp', 1994),
#  ('cassandra', 1993),
#  ('sql-server-2012', 1993),
#  ('fonts', 1985),
#  ('lua', 1983),
#  ('terminal', 1981),
#  ('uiviewcontroller', 1965),
#  ('merge', 1961),
#  ('excel-formula', 1961),
#  ('ffmpeg', 1961),
#  ('types', 1960),
#  ('emacs', 1959),
#  ('responsive-design', 1951),
#  ('datatable', 1945),
#  ('sqlite3', 1944),
#  ('redis', 1940),
#  ('google-spreadsheet', 1934),
#  ('build', 1929),
#  ('joomla', 1926),
#  ('nullpointerexception', 1921),
#  ('colors', 1915),
#  ('graphics', 1913),
#  ('push-notification', 1909),
#  ('asp.net-mvc-5', 1906),
#  ('constructor', 1903),
#  ('drupal', 1896),
#  ('hyperlink', 1895),
#  ('memory-leaks', 1891),
#  ('ssis', 1890),
#  ('android-asynctask', 1889),
#  ('syntax', 1886),
#  ('socket.io', 1877),
#  ('laravel-4', 1873),
#  ('io', 1869),
#  ('parse.com', 1868),
#  ('clojure', 1868),
#  ('parameters', 1867),
#  ('module', 1866),
#  ('concurrency', 1863),
#  ('enums', 1857),
#  ('web-applications', 1847),
#  ('count', 1842),
#  ('proxy', 1836),
#  ('bluetooth', 1835),
#  ('bitmap', 1834),
#  ('group-by', 1824),
#  ('three.js', 1823),
#  ('devise', 1817),
#  ('url-rewriting', 1798),
#  ('oauth-2.0', 1796),
#  ('kotlin', 1794),
#  ('combobox', 1788),
#  ('parallel-processing', 1785),
#  ('datatables', 1783),
#  ('compiler-errors', 1782),
#  ('arduino', 1778),
#  ('server', 1775),
#  ('cmake', 1770),
#  ('java-8', 1768),
#  ('datepicker', 1766),
#  ('casting', 1760),
#  ('linked-list', 1740),
#  ('interface', 1731),
#  ('xamarin.android', 1730),
#  ('triggers', 1726),
#  ('menu', 1724),
#  ('scope', 1718),
#  ('youtube', 1711),
#  ('properties', 1709),
#  ('process', 1706),
#  ('flex', 1706),
#  ('autocomplete', 1703),
#  ('swift2', 1697),
#  ('promise', 1686),
#  ('download', 1681),
#  ('javascript-events', 1674),
#  ('callback', 1662),
#  ('google-api', 1659),
#  ('beautifulsoup', 1656),
#  ('phpmyadmin', 1649),
#  ('ant', 1648),
#  ('safari', 1642),
#  ('compilation', 1641),
#  ('controller', 1640),
#  ('scikit-learn', 1639),
#  ('ms-word', 1639),
#  ('pagination', 1636),
#  ('model', 1636),
#  ('3d', 1633),
#  ('xamarin.ios', 1628),
#  ('android-ndk', 1627),
#  ('opengl-es', 1625),
#  ('ionic2', 1623),
#  ('get', 1615),
#  ('grep', 1611),
#  ('path', 1609),
#  ('configuration', 1608),
#  ('outlook', 1605),
#  ('notifications', 1605),
#  ('permissions', 1599),
#  ('linux-kernel', 1598),
#  ('orm', 1590),
#  ('shiny', 1585),
#  ('tree', 1584),
#  ('scipy', 1583),
#  ('functional-programming', 1581),
#  ('libgdx', 1577),
#  ('cron', 1576),
#  ('tabs', 1576),
#  ('datagrid', 1575),
#  ('nhibernate', 1575),
#  ('jboss', 1575),
#  ('exception-handling', 1569),
#  ('reference', 1548),
#  ('null', 1548),
#  ('xml-parsing', 1548),
#  ('dns', 1545),
#  ('sqlalchemy', 1542),
#  ('eloquent', 1540),
#  ('camera', 1538),
#  ('macros', 1535),
#  ('automation', 1527),
#  ('yii2', 1524),
#  ('static', 1522),
#  ('sprite-kit', 1512),
#  ('coldfusion', 1512),
#  ('sql-server-2008-r2', 1508),
#  ('version-control', 1507),
#  ('routes', 1504),
#  ('gulp', 1503),
#  ('neural-network', 1495),
#  ('pyspark', 1494),
#  ('webforms', 1487),
#  ('f#', 1483),
#  ('ftp', 1481),
#  ('onclick', 1480),
#  ('upload', 1477),
#  ('binding', 1471),
#  ('background', 1469),
#  ('hashmap', 1464),
#  ('insert', 1462),
#  ('mapreduce', 1462),
#  ('flexbox', 1460),
#  ('sdk', 1443),
#  ('django-rest-framework', 1437),
#  ('character-encoding', 1436),
#  ('active-directory', 1436),
#  ('routing', 1434),
#  ('transactions', 1429),
#  ('x86', 1424),
#  ('android-viewpager', 1421),
#  ('stl', 1414),
#  ('cuda', 1405),
#  ('jquery-plugins', 1402),
#  ('cocos2d-iphone', 1399),
#  ('calendar', 1394),
#  ('xsd', 1393),
#  ('uiscrollview', 1392),
#  ('jackson', 1391),
#  ('coffeescript', 1389),
#  ('android-edittext', 1386),
#  ('request', 1384),
#  ('architecture', 1384),
#  ('uicollectionview', 1383),
#  ('raspberry-pi', 1378),
#  ('django-forms', 1377),
#  ('struts2', 1375),
#  ('crystal-reports', 1371),
#  ('android-gradle', 1369),
#  ('async-await', 1368),
#  ('sas', 1365),
#  ('kubernetes', 1360),
#  ('pyqt', 1360),
#  ('jasmine', 1359),
#  ('centos', 1348),
#  ('openssl', 1339),
#  ('laravel-5.2', 1337),
#  ('binary', 1335),
#  ('dplyr', 1333),
#  ('drupal-7', 1328),
#  ('jmeter', 1326),
#  ('stream', 1317),
#  ('scrapy', 1316),
#  ('installation', 1307),
#  ('uiwebview', 1302),
#  ('visual-studio-code', 1301),
#  ('drag-and-drop', 1297),
#  ('nested', 1297),
#  ('access-vba', 1296),
#  ('linker', 1294),
#  ('floating-point', 1293),
#  ('pygame', 1293),
#  ('android-emulator', 1293),
#  ('char', 1291),
#  ('msbuild', 1291),
#  ('crash', 1290),
#  ('apache-kafka', 1288),
#  ('prolog', 1287),
#  ('lucene', 1287),
#  ('textview', 1287),
#  ('scripting', 1277),
#  ('windows-8', 1274),
#  ('console', 1273),
#  ('navigation', 1270),
#  ('dialog', 1268),
#  ('listbox', 1267),
#  ('keras', 1265),
#  ('iterator', 1263),
#  ('sql-server-2005', 1262),
#  ('rotation', 1260),
#  ('cors', 1259),
#  ('django-templates', 1256),
#  ('json.net', 1256),
#  ('jqgrid', 1250),
#  ('textbox', 1241),
#  ('gruntjs', 1236),
#  ('uibutton', 1235),
#  ('xampp', 1233),
#  ('pip', 1231),
#  ('nosql', 1228),
#  ('android-actionbar', 1228),
#  ('localization', 1227),
#  ('storyboard', 1226),
#  ('jaxb', 1224),
#  ('eclipse-plugin', 1222),
#  ('geolocation', 1219),
#  ('jersey', 1214),
#  ('uinavigationcontroller', 1210),
#  ('gps', 1209),
#  ('dart', 1208),
#  ('uiimageview', 1207),
#  ('wso2', 1207),
#  ('html5-canvas', 1206),
#  ('fortran', 1204),
#  ('webdriver', 1203),
#  ('jframe', 1198),
#  ('google-drive-sdk', 1195),
#  ('dojo', 1194),
#  ('sum', 1191),
#  ('google-cloud-platform', 1190),
#  ('cryptography', 1189),
#  ('header', 1189),
#  ('nlp', 1188),
#  ('segmentation-fault', 1187),
#  ('duplicates', 1186),
#  ('visual-studio-2017', 1186),
#  ('deep-learning', 1183),
#  ('asp-classic', 1182),
#  ('ionic3', 1182),
#  ('keyboard', 1175),
#  ('statistics', 1171),
#  ('map', 1168),
#  ('sonarqube', 1165),
#  ('annotations', 1163),
#  ('django-views', 1161),
#  ('zend-framework2', 1158),
#  ('angular-ui-router', 1151),
#  ('garbage-collection', 1151),
#  ('type-conversion', 1151),
#  ('arm', 1150),
#  ('mfc', 1150),
#  ('computer-vision', 1149),
#  ('imageview', 1149),
#  ('serial-port', 1148),
#  ('.net-core', 1148),
#  ('angularjs-scope', 1147),
#  ('compiler-construction', 1145),
#  ('xmlhttprequest', 1143),
#  ('ldap', 1134),
#  ('autolayout', 1130),
#  ('rust', 1127),
#  ('int', 1125),
#  ('delegates', 1124),
#  ('return', 1124),
#  ('apache-camel', 1122),
#  ('directory', 1120),
#  ('uiimage', 1119),
#  ('entity-framework-6', 1118),
#  ('numbers', 1116),
#  ('mocking', 1115),
#  ('namespaces', 1114),
#  ('requirejs', 1112),
#  ('telerik', 1112),
#  ('format', 1111),
#  ('youtube-api', 1111),
#  ('operating-system', 1110),
#  ('twig', 1109),
#  ('css-selectors', 1109),
#  ('network-programming', 1105),
#  ('mono', 1104),
#  ('jvm', 1102),
#  ('modal-dialog', 1102),
#  ('integer', 1097),
#  ('formatting', 1095),
#  ('timestamp', 1095),
#  ('vuejs2', 1092),
#  ('protractor', 1091),
#  ('windows-7', 1090),
#  ('grid', 1086),
#  ('rabbitmq', 1086),
#  ('react-router', 1085),
#  ('attributes', 1080),
#  ('popup', 1078),
#  ('smtp', 1075),
#  ('hover', 1075),
#  ('com', 1074),
#  ('set', 1072),
#  ('internet-explorer-8', 1072),
#  ('switch-statement', 1070),
#  ('http-headers', 1068),
#  ('firebase-authentication', 1068),
#  ('boolean', 1066),
#  ('doctrine', 1064),
#  ('wsdl', 1062),
#  ('spring-data', 1061),
#  ('jasper-reports', 1061),
#  ('timezone', 1059),
#  ('frameworks', 1058),
#  ('passwords', 1057),
#  ('docker-compose', 1055),
#  ('radio-button', 1052),
#  ('linq-to-sql', 1050),
#  ('google-play', 1049),
#  ('ef-code-first', 1048),
#  ('initialization', 1048),
#  ('wix', 1048),
#  ('db2', 1046),
#  ('composer-php', 1046),
#  ('sbt', 1046),
#  ('internationalization', 1045),
#  ('event-handling', 1041),
#  ('spring-data-jpa', 1041),
#  ('google-visualization', 1038),
#  ('save', 1035),
#  ('find', 1029),
#  ('windows-10', 1025),
#  ('slider', 1025),
#  ('jni', 1022),
#  ('rubygems', 1019),
#  ('bootstrap-4', 1019),
#  ('qml', 1015),
#  ('nuget', 1014),
#  ('phantomjs', 1013),
#  ('mongodb-query', 1013),
#  ('dependencies', 1013),
#  ('sharepoint-2010', 1012),
#  ('playframework-2.0', 1010),
#  ('realm', 1008),
#  ('react-redux', 1008),
#  ('udp', 1005),
#  ('rxjs', 1005),
#  ('arguments', 1004),
#  ('ansible', 1003),
#  ('vb6', 1001),
#  ('tags', 1001),
#  ('windows-phone', 1001),
#  ('apache-spark-sql', 999),
#  ('include', 999),
#  ('stack', 997),
#  ('google-cloud-messaging', 995),
#  ('location', 993),
#  ('ruby-on-rails-3.2', 993),
#  ('resize', 991),
#  ('debian', 985),
#  ('leaflet', 984),
#  ('multiprocessing', 984),
#  ('python-requests', 984),
#  ('synchronization', 979),
#  ('windows-runtime', 978),
#  ('jtable', 977),
#  ('continuous-integration', 976),
#  ('data.table', 975),
#  ('ip', 974),
#  ('openerp', 973),
#  ('ckeditor', 972),
#  ('sql-update', 972),
#  ('copy', 971),
#  ('in-app-purchase', 968),
#  ('pycharm', 968),
#  ('gdb', 967),
#  ('polymorphism', 965),
#  ('g++', 964),
#  ('command', 964),
#  ('salesforce', 963),
#  ('ruby-on-rails-3.1', 963),
#  ('xna', 958),
#  ('windows-store-apps', 957),
#  ('package', 957),
#  ('order', 957),
#  ('subprocess', 957),
#  ('append', 956),
#  ('foreign-keys', 953),
#  ('aws-lambda', 952),
#  ('widget', 952),
#  ('uitextfield', 951),
#  ('admob', 949),
#  ('click', 944),
#  ('queue', 939),
#  ('cursor', 938),
#  ('jpanel', 937),
#  ('itext', 936),
#  ('mockito', 935),
#  ('google-bigquery', 934),
#  ('.net-4.0', 934),
#  ('phpunit', 932),
#  ('time-series', 929),
#  ('localhost', 929),
#  ('base64', 929),
#  ('ide', 929),
#  ('glassfish', 926),
#  ('broadcastreceiver', 926),
#  ('erlang', 925),
#  ('connection', 924),
#  ('user-controls', 924),
#  ('iis-7', 923),
#  ('apache-poi', 921),
#  ('vsts', 918),
#  ('gson', 917),
#  ('asp.net-web-api2', 915),
#  ('angularjs-ng-repeat', 914),
#  ('log4j', 914),
#  ('kernel', 914),
#  ('asp.net-core-mvc', 913),
#  ('fragment', 911),
#  ('maps', 911),
#  ('subquery', 909),
#  ('position', 907),
#  ('tuples', 905),
#  ('handlebars.js', 904),
#  ('vagrant', 903),
#  ('geometry', 903),
#  ('cross-browser', 903),
#  ('less', 902),
#  ('syntax-error', 900),
#  ('ado.net', 898),
#  ('actionscript', 898),
#  ('compare', 896),
#  ('kendo-grid', 895),
#  ('wordpress-plugin', 890),
#  ('http-post', 890),
#  ('dataset', 886),
#  ('icons', 882),
#  ('web-config', 882),
#  ('akka', 880),
#  ('cucumber', 879),
#  ('spark-dataframe', 879),
#  ('gmail', 879),
#  ('certificate', 879),
#  ('window', 878),
#  ('double', 877),
#  ('clang', 877),
#  ('hbase', 872),
#  ('output', 872),
#  ('signalr', 871),
#  ('printf', 871),
#  ('substring', 870),
#  ('cypher', 867),
#  ('mocha', 867),
#  ('web-crawler', 865),
#  ('automated-tests', 865),
#  ('win-universal-app', 865),
#  ('key', 864),
#  ('applet', 863),
#  ('range', 860),
#  ('pthreads', 860),
#  ('django-admin', 860),
#  ('elixir', 857),
#  ('google-play-services', 856),
#  ('website', 856),
#  ('apple-push-notifications', 855),
#  ('pattern-matching', 855),
#  ('label', 854),
#  ('jquery-selectors', 852),
#  ('mule', 851),
#  ('zip', 851),
#  ('android-sqlite', 851),
#  ('migration', 846),
#  ('ios6', 845),
#  ('visual-studio-2008', 844),
#  ('ssl-certificate', 842),
#  ('treeview', 842),
#  ('pipe', 841),
#  ('pivot', 841),
#  ('imagemagick', 839),
#  ('bigdata', 839),
#  ('ibm-mobilefirst', 839),
#  ('styles', 838),
#  ('conditional', 837),
#  ('resources', 833),
#  ('malloc', 833),
#  ('hex', 833),
#  ('hdfs', 832),
#  ('anaconda', 831),
#  ('firefox-addon', 831),
#  ('typo3', 830),
#  ('iteration', 829),
#  ('alignment', 829),
#  ('wordpress-theming', 829),
#  ('runtime-error', 827),
#  ('fullcalendar', 827),
#  ('blackberry', 827),
#  ('jsoup', 826),
#  ('tinymce', 826),
#  ('asp.net-identity', 825),
#  ('uilabel', 825),
#  ('media-queries', 825),
#  ('ejb', 823),
#  ('nsstring', 823),
#  ('laravel-5.1', 823),
#  ('android-camera', 823),
#  ('applescript', 822),
#  ('ibm-cloud', 821),
#  ('odbc', 821),
#  ('timeout', 820),
#  ('sms', 818),
#  ('air', 817),
#  ('environment-variables', 816),
#  ('singleton', 814),
#  ('filesystems', 812),
#  ('app-store', 811),
#  ('cygwin', 808),
#  ('bluetooth-lowenergy', 807),
#  ('thread-safety', 806),
#  ('liferay', 805),
#  ('sharedpreferences', 805),
#  ('google-chrome-devtools', 804),
#  ('gem', 804),
#  ('qt5', 803),
#  ('polymer', 802),
#  ('angular5', 799),
#  ('amazon-dynamodb', 797),
#  ('sitecore', 797),
#  ('usb', 797),
#  ('html5-video', 796),
#  ('rss', 796),
#  ('closures', 795),
#  ('webkit', 794),
#  ('ssrs-2008', 793),
#  ('cocoapods', 791),
#  ('ipython', 790),
#  ('jwt', 790),
#  ('webserver', 789),
#  ('firebase-cloud-messaging', 789),
#  ('testng', 788),
#  ('out-of-memory', 787),
#  ('repository', 786),
#  ('underscore.js', 783),
#  ('ms-access-2010', 782),
#  ('tomcat7', 782),
#  ('authorization', 781),
#  ('video-streaming', 780),
#  ('tableview', 780),
#  ('xcode5', 780),
#  ('seo', 778),
#  ('jupyter-notebook', 778),
#  ('install', 777),
#  ('tcl', 776),
#  ('export', 775),
#  ('electron', 775),
#  ('kivy', 774),
#  ('gitlab', 773),
#  ('angular-material', 773),
#  ('apache2', 773),
#  ('mercurial', 772),
#  ('gtk', 771),
#  ('many-to-many', 771),
#  ('android-webview', 769),
#  ('local-storage', 768),
#  ('pug', 768),
#  ('jax-rs', 766),
#  ('aggregation-framework', 765),
#  ('zurb-foundation', 764),
#  ('embedded', 764),
#  ('parameter-passing', 764),
#  ('android-service', 762),
#  ('jquery-animate', 761),
#  ('global-variables', 761),
#  ('awt', 760),
#  ('logic', 760),
#  ('match', 760),
#  ('wxpython', 759),
#  ('ember-data', 759),
#  ('jetty', 759),
#  ('excel-2010', 757),
#  ('jms', 755),
#  ('jquery-validate', 755),
#  ('locking', 754),
#  ('ios9', 753),
#  ('extjs4', 751),
#  ('xcode7', 750),
#  ('operator-overloading', 750),
#  ('report', 748),
#  ('escaping', 747),
#  ('load', 747),
#  ('compression', 747),
#  ('max', 746),
#  ('try-catch', 743),
#  ('devexpress', 742),
#  ('ruby-on-rails-5', 741),
#  ('cloud', 740),
#  ('notepad++', 739),
#  ('scheme', 739),
#  ('relational-database', 739),
#  ('client', 737),
#  ('twilio', 737),
#  ('windows-installer', 737),
#  ('sails.js', 735),
#  ('themes', 735),
#  ('windows-services', 735),
#  ('touch', 735),
#  ('oracle10g', 732),
#  ('mapping', 731),
#  ('retrofit', 727),
#  ('uikit', 726),
#  ...]

# %% [markdown]
# ## Use `spacy` to tokenize and lemmatize data
# - Remove stop words
# - Calculate tf-idf vectors

# %% [markdown]
# `Spacy` could probably lemmatize the list of tags for me as well.

# %%
doc = nlp(df['Data'].values[1])

# %%
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_, token.shape_, token.is_alpha, token.is_stop)
# Out:
# find find VERB VB ROOT xxxx True False
# array array NOUN NN compound xxxx True False
# item item NOUN NN dobj xxxx True False
# in in ADP IN prep xx True False
# PHP php PROPN NNP compound XXX True False
# php php NOUN NN pobj xxx True False
